# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('alert_data.csv')
df
# Out:
#           timestamp       ear      gaze    roll   pitch      yaw  tired  \
# 0     170529.451832  0.376073  0.005519  [9.73]  [9.18]   [2.29]      0
# 1     170529.976890  0.346200  0.006764  [9.72]  [8.26]   [2.15]      0
# 2     170530.023496  0.348171  0.007035  [9.74]    [8.]   [2.37]      0
# 3     170530.069533  0.363759  0.007826  [9.68]  [8.26]   [2.03]      0
# 4     170530.101387  0.346410  0.007556   [10.]  [8.17]   [2.36]      0
# ...             ...       ...       ...     ...     ...      ...    ...
# 4364  170675.575754  0.241423  0.005909  [0.34]  [6.67]  [-3.72]      0
# 4365  170675.607178  0.254034  0.006375  [0.78]  [6.68]  [-2.71]      0
# 4366  170675.637865  0.251957  0.006219  [0.73]  [7.09]  [-2.69]      0
# 4367  170675.669503  0.260520  0.007245  [0.82]  [6.86]  [-2.82]      0
# 4368  170675.699657  0.246365  0.007992  [0.93]    [7.]  [-2.55]      0
#
#       asleep  looking_away  distracted
# 0          0             0           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4369 entries, 0 to 4368
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     4369 non-null   float64
#  1   ear           4369 non-null   float64
#  2   gaze          4369 non-null   float64
#  3   roll          4369 non-null   float64
#  4   pitch         4369 non-null   float64
#  5   yaw           4369 non-null   float64
#  6   tired         4369 non-null   int64
#  7   asleep        4369 non-null   int64
#  8   looking_away  4369 non-null   int64
#  9   distracted    4369 non-null   int64
# dtypes: float64(6), int64(4)
# memory usage: 341.5 KB

# %%
# quitar los [] de las columnas
df['roll'] = df['roll'].str.strip('[]')
df['roll'] = df['roll'].astype(float)
df['pitch'] = df['pitch'].str.strip('[]')
df['pitch'] = df['pitch'].astype(float)
df['yaw'] = df['yaw'].str.strip('[]')
df['yaw'] = df['yaw'].astype(float)

# %%
df['distracted'].value_counts()
# Out:
# distracted
# 0    3251
# 1    1118
# Name: count, dtype: int64

# %%
# plot time series of the data
plt.figure(figsize=(15, 6))
plt.plot(df.index, df['distracted'])

# %%
# plot time series of the data
plt.figure(figsize=(15, 6))
plt.plot(df.index, df['ear'])
plt.plot(df.index, df['distracted'])

# %%
plt.figure(figsize=(15, 6))
plt.plot(df.index, df['roll'])

# %%
# Plotting the data
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='ear', data=df, palette='viridis')
plt.title('Alert Type Distribution')
# Out:
# Text(0.5, 1.0, 'Alert Type Distribution')
# Error in callback <function flush_figures at 0x0000019C91B40900> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df
# Out:
#                          timestamp       ear      gaze    roll   pitch  \
# 0    1970-01-01 00:00:00.000170529  0.376073  0.005519  [9.73]  [9.18]
# 1    1970-01-01 00:00:00.000170529  0.346200  0.006764  [9.72]  [8.26]
# 2    1970-01-01 00:00:00.000170530  0.348171  0.007035  [9.74]    [8.]
# 3    1970-01-01 00:00:00.000170530  0.363759  0.007826  [9.68]  [8.26]
# 4    1970-01-01 00:00:00.000170530  0.346410  0.007556   [10.]  [8.17]
# ...                            ...       ...       ...     ...     ...
# 4364 1970-01-01 00:00:00.000170675  0.241423  0.005909  [0.34]  [6.67]
# 4365 1970-01-01 00:00:00.000170675  0.254034  0.006375  [0.78]  [6.68]
# 4366 1970-01-01 00:00:00.000170675  0.251957  0.006219  [0.73]  [7.09]
# 4367 1970-01-01 00:00:00.000170675  0.260520  0.007245  [0.82]  [6.86]
# 4368 1970-01-01 00:00:00.000170675  0.246365  0.007992  [0.93]    [7.]
#
#           yaw  tired  asleep  looking_away  distracted
# 0      [2.29]      0       0             0           0
# ...
